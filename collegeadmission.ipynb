# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharshini479/Data_Science/blob/main/collegeadmission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %%
# Load dataset
df = pd.read_csv('/content/student_performance.csv')
print(df.head())
# Out:
#    High_School_GPA  Extracurricular_Activities  Parental_Income  \
# 0              3.8                           3            55000
# 1              3.2                           1            40000
# 2              4.0                           4            72000
# 3              2.9                           2            35000
# 4              3.5                           0            50000
#
#    Hours_Studied_Per_Week  Entrance_Test_Score  Distance_From_College  \
# 0                      15                   87                      5
# 1                      10                   75                     20
# 2                      18                   92                     10
# 3                       6                   65                     30
# 4                      12                   78                      8
#
#   Internet_At_Home Final_Result
# 0              Yes            A
# 1               No            B
# 2              Yes            A
# ...

# %%
# Basic Info
print("📋 Dataset Info:")
print(df.info())
# Out:
# 📋 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   High_School_GPA             10 non-null     float64
#  1   Extracurricular_Activities  10 non-null     int64
#  2   Parental_Income             10 non-null     int64
#  3   Hours_Studied_Per_Week      10 non-null     int64
#  4   Entrance_Test_Score         10 non-null     int64
#  5   Distance_From_College       10 non-null     int64
#  6   Internet_At_Home            10 non-null     object
#  7   Final_Result                10 non-null     object
# dtypes: float64(1), int64(5), object(2)
# memory usage: 772.0+ bytes
# None

# %%
# Check for missing values
print("\n❓ Missing Values:\n", df.isnull().sum())
# Out:
# ❓ Missing Values:
#  High_School_GPA               0
# Extracurricular_Activities    0
# Parental_Income               0
# Hours_Studied_Per_Week        0
# Entrance_Test_Score           0
# Distance_From_College         0
# Internet_At_Home              0
# Final_Result                  0
# dtype: int64

# %%
# Summary statistics
print("\n📊 Statistical Summary:")
print(df.describe())
# Out:
# 📊 Statistical Summary:
#        High_School_GPA  Extracurricular_Activities  Parental_Income  \
# count        10.000000                   10.000000         10.00000
# mean          3.380000                    2.300000      51200.00000
# std           0.487169                    1.494434      15942.95386
# min           2.500000                    0.000000      30000.00000
# 25%           3.050000                    1.250000      40500.00000
# 50%           3.400000                    2.000000      49000.00000
# 75%           3.775000                    3.000000      58750.00000
# max           4.000000                    5.000000      80000.00000
#
#        Hours_Studied_Per_Week  Entrance_Test_Score  Distance_From_College
# count                10.00000             10.00000              10.000000
# mean                 12.20000             78.00000              15.800000
# std                   4.98442             12.03698              11.153475
# ...

# %%
# Correlation heatmap for numeric features
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.countplot(data=df, x='Final_Result')
plt.title("Distribution of Final Results")
# Out:
# Text(0.5, 1.0, 'Distribution of Final Results')
